# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.pyplot import figure

# fig = plt.figure(figsize=(6, 3))
# plt.rcParams.update({'font.size': 12})
# figj = 1

df = pd.read_csv("data/se-survey-results.csv")
#print(df.head())


# ax = fig.add_subplot(1,2,figj)
# figj = figj + 1

# #ax.bar(df.app,df.x, color="palegreen")

# plt.tight_layout()
# plt.show()
# Out:
#            Timestamp Age Range Gender Identity            Education level   \
# 0  4/5/2022 17:41:15   21 - 29           Woman  Some college but no degree
# 1  4/5/2022 17:41:21   18 - 21           Woman  Some college but no degree
#
#   Employment Status  \
# 0          Employed
# 1          Employed
#
#   How important to you are your security practices for different purposes of your internet usage?  [Entertainment]  \
# 0                                           Slightly
# 1                                          Important
#
#   How important to you are your security practices for different purposes of your internet usage?  [Social]  \
# 0                                               Very
# 1                                             Fairly
#
#   How important to you are your security practices for different purposes of your internet usage?  [Games]  \
# 0                                          Important
# 1                                             Fairly
#
#   How important to you are your security practices for different purposes of your internet usage?  [Banking]  \
# 0                                               Very
# 1                                               Very
#
#   How important to you are your security practices for different purposes of your internet usage?  [Shopping]  \
# 0                                               Very
# 1                                             Fairly
#
#    ...  \
# 0  ...
# 1  ...
#
#   Please rate your familiarity with various security topics: [Social engineering]  \
# 0                                         Completely
# 1                                             Mostly
#
#   Please rate your familiarity with various security topics: [Phishing]  \
# 0                                         Completely
# 1                                             Mostly
#
#   Please rate your familiarity with various security topics: [Man-in-the-middle attack]  \
# 0                                             Mostly
# 1                                             Mostly
#
#    If you were offered an online free course about cybersecurity and privacy, would you be interested in joining the course?  \
# 0                                              Maybe
# 1                                                Yes
#
#   If you would be interested in joining a course about cybersecurity and privacy, how much time are you willing to allocate during a day?  \
# 0                    Between 10 and 30 minutes a day
# 1                    Between 10 and 30 minutes a day
#
#   Do you use the same password for most of your accounts?  \
# 0                                                Yes
# 1                                                Yes
#
#   Do you share some of your passwords with your friends or family members?   \
# 0                                                 No
# 1                                                 No
#
#   If the bank calls you and asks for your password as verification, would you give it to them?  \
# 0                                                 No
# 1                                                 No
#
#   If you got an email to update your log in information via a link, would you click the link?  \
# 0                                                 No
# 1                                                 No
#
#   Would you pay to retrieve your data if you are the victim of a ransomware attack?
# 0                                                 No
# 1                                                 No
#
# [2 rows x 32 columns]
